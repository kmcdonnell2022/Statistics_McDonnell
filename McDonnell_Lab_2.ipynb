# %% [markdown]
# <a href="https://colab.research.google.com/github/kmcdonnell2022/Statistics_McDonnell/blob/main/McDonnell_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #importing mathplotlibrary

# %%
labels = ['frogs', 'dogs' , 'cats', 'birds']
sizes = [15,30,45,10]
explode = (0,0.1,0,0) 
fig1,ax1 = plt.subplots()
ax1.pie(sizes, explode = explode, labels =labels,autopct = '%1.1f%%' ,shadow=True , startangle=90)
ax1.axis('equal')
#how to code for a pie chart
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
labels = ['hats', 'pants' , 'socks', 'hoodie']
sizes = [15,30,45,10]
explode = (0,0.1,0,0) 
fig1,ax1 = plt.subplots()
ax1.pie(sizes, explode = explode, labels =labels,autopct = '%1.1f%%' ,shadow=True , startangle=90)
ax1.axis('equal')
#tried w/ different vaiables
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
name = 'kyle'

# %%
name
# Out:
# 'kyle'

# %%
f"hello my name is {name}" #f-string allows us to put in a given varibale to a situation when applied
# Out:
# 'hello my name is kyle'

# %% [markdown]
# #Files

# %%
f = open("hello.txt", 'w') #this allows us to open a file in the background. If you checl the "files" youll see it in there ('w'means write file; it has to be there for it to work) files will not save automatically
data = "hellow world"
print(data,file = f)
f.close()

# %%
f = open("hello.txt" , 'r') #this allows the program to read a file back to me. 'r' signifies the command, read
lines = f.readlines()
print(lines) 
f.close()
# Out:
# ['hellow world\n']

# %% [markdown]
# #Coin Flip

# %%
import numpy as np

# %%
np.random.random() #gives a random number
# Out:
# 0.8895169383615411

# %%
for index in range(10): #told machine to count 0-9 and display it
  print(index, np.random.random() ) #did the same, but random numbers
# Out:
# 0 0.5749182980775266
# 1 0.8471152622021495
# 2 0.41706369495411455
# 3 0.857549979357353
# 4 0.19683700101031432
# 5 0.9886516322336608
# 6 0.2741715898017276
# 7 0.5895043062068464
# 8 0.25580588467464394
# 9 0.6852044731767604

# %%
for i in range (10): #i is just another name for index
  print( i, np.random.random() )
# Out:
# 0 0.9039307413179158
# 1 0.28798210850052053
# 2 0.9470872074057415
# 3 0.19789144714963547
# 4 0.21941521568102051
# 5 0.7739229760865449
# 6 0.4444727349479002
# 7 0.4151488540437752
# 8 0.901394900787974
# 9 0.2120657464277833

# %%
for step in range(10): #adding the words to the program 
  print( step, "Hello, your number is:" , np.random.random() )
# Out:
# 0 Hello, your number is: 0.20168163078837342
# 1 Hello, your number is: 0.8510179483244026
# 2 Hello, your number is: 0.22182597709975116
# 3 Hello, your number is: 0.007860549063629985
# 4 Hello, your number is: 0.9829691060633393
# 5 Hello, your number is: 0.16357099218680826
# 6 Hello, your number is: 0.6709974663941415
# 7 Hello, your number is: 0.6550397841029899
# 8 Hello, your number is: 0.5865570551487748
# 9 Hello, your number is: 0.046671519053133714

# %%
np.random.random() > 0.5 #one coin flip
# Out:
# False

# %%
np.random.random() > 0.5
# Out:
# True

# %%
np.random.random() > 0.5
# Out:
# False

# %%
for flip in range (10): # coin flip generator <0.5= heads (false)  >0.5 = tails (true). program tells us if number generated is higher or lower than 0.5 thus, heads or tails
  print(np.random.random() > 0.5 )
# Out:
# False
# True
# True
# True
# True
# False
# True
# False
# True
# True

# %%
for flip in range (10):  #assigned heads and tails to true or false 
  coin = np.random.random() > 0.5 
  if coin == True: 
    print ("Heads")
  else: 
      print ("Tails")
# Out:
# Tails
# Heads
# Tails
# Heads
# Heads
# Heads
# Heads
# Heads
# Tails
# Heads

# %% [markdown]
# #Functions

# %%
def flip_coin():  #defining flip coin (verb) verbs must be followed by ()
  coin = np.random.random() > 0.5 
  if coin == True: 
    print ("Heads")
  else: 
    print ("Tails")

# %%
flip_coin() #told program to flip a coin
# Out:
# Heads

# %%
for i in range(10): #flipped 10 coins 
    flip_coin()
# Out:
# Tails
# Heads
# Heads
# Tails
# Heads
# Heads
# Heads
# Heads
# Heads
# Heads

# %% [markdown]
# #graphics

# %%
from IPython.core.display import display, HTML

# %%
display(HTML('<h1>Hello World </h1>'))
# Out:
# <h1>Hello World </h1>

# %%
coin_heads_url = "https://i5.walmartimages.com/asr/3850a9da-7ed7-4bbd-915a-3a8e38e0195a_1.83cc29729d27461002ccd2748d4a3a5f.jpeg" #inserted head link

# %%
coin_tails_url = "https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg" #onserted tail link

# %%
display( HTML ('<img src="https://i5.walmartimages.com/asr/3850a9da-7ed7-4bbd-915a-3a8e38e0195a_1.83cc29729d27461002ccd2748d4a3a5f.jpeg" > ')) #dlisplay the image
# Out:
# <img src="https://i5.walmartimages.com/asr/3850a9da-7ed7-4bbd-915a-3a8e38e0195a_1.83cc29729d27461002ccd2748d4a3a5f.jpeg" >

# %%
display( HTML ('<img src= "https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg" > ')) #display image of coin
# Out:
# <img src= "https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg" >

# %%
def show_img (img_url):                                   #changing size of coins 
    display(HTML('<img src ='+ img_url + ' width = 100>'))

# %%
show_img(coin_heads_url)  #showing the coin w new size
# Out:
# <img src =https://i5.walmartimages.com/asr/3850a9da-7ed7-4bbd-915a-3a8e38e0195a_1.83cc29729d27461002ccd2748d4a3a5f.jpeg width = 100>

# %%
show_img(coin_tails_url) #showimg new size again
# Out:
# <img src =https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg width = 100>

# %%
heads = 'https://i5.walmartimages.com/asr/3850a9da-7ed7-4bbd-915a-3a8e38e0195a_1.83cc29729d27461002ccd2748d4a3a5f.jpeg' #assinging link to head and tails 
tails = 'https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg'

# %%
def flip_coin(): 
  if np.random.random() > 0.5
      show_img(heads)
  else:
      show_img(tails)
# Out:
#   File "<ipython-input-104-c09608846927>", line 2
#     if np.random.random() > 0.5
#                                ^
# SyntaxError: invalid syntax
